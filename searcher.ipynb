# %%
import json
import typing as t
from pathlib import Path

import itertools as it
import abc
import time
from overrides import overrides

import asyncio
import logging


from config import CONFIGURATION
from utils.logger import setup_logging


from copy import deepcopy
from operator import itemgetter

from elasticsearch import Elasticsearch
from overrides import overrides


import numpy as np
import tensorflow as tf
import keras, keras.layers as L
from utils.utils import Vocab, load, infer_mask, read_conll
from utils.conlleval import evaluate
from tqdm import tqdm
from IPython.display import clear_output
import matplotlib.pyplot as plt
from collections import defaultdict
# %matplotlib inline
from textblob import TextBlob
import gensim
from gensim.models.word2vec import Word2Vec
import gensim.downloader as api
from sklearn.model_selection import train_test_split
# Out:
# Using TensorFlow backend.

# %%
def preprocessing(texts):
    for i,text in enumerate(texts):   
        text = (''.join(text.lower()))
        texts[i] = text.replace('\n', '')
    return texts

# %%
# Определение степени принадлежности к категории Еда или Спорт для выделения Item для запроса
class IntentClassifier():
    def __init__(self, w2v_ru_fpath="all.norm-sz100-w10-cb0-it1-min100.w2v", w2v_en_model = 'glove-twitter-50'):
        self.w2v_ru = gensim.models.KeyedVectors.load_word2vec_format(w2v_ru_fpath, binary=True, unicode_errors='ignore')
        self.w2v_ru.init_sims(replace=True)        
        self.w2v_en = api.load(w2v_en_model)
        
        self.catigories_en = np.zeros((2,50))
        self.catigories_en[0] = self.w2v_en.get_vector('food')
        self.catigories_en[1] = self.w2v_en.get_vector('sport')
        
        self.catigories_ru = np.zeros((2,100))
        self.catigories_ru[0] = self.w2v_ru.get_vector('еда')
        self.catigories_ru[1] = self.w2v_ru.get_vector('спорт')
        
    def classify(self, word):
        try:
            language = TextBlob(word).detect_language()
        except:
            print ('short word')
            return (np.array((-1,-2)))            
            
        try:
            if language == 'ru':
                sim = self.w2v_ru.cosine_similarities(self.w2v_ru.get_vector(word),self.catigories_ru)
                return (np.array((np.argmax(sim), np.max(sim))))
            else :
                sim = self.w2v_en.cosine_similarities(self.w2v_en.get_vector(word),self.catigories_en)
                return (np.array((np.argmax(sim), np.max(sim))))
        except : 
            print ('unknown word - ', word)
            return (np.array((-1,-2)))

# %% [markdown]
# # Named-entity recognition
# Инициализация и обучение

# %%
data = read_conll('123g.txt', lower_words=True)

# %%
tf.reset_default_graph()
sess = tf.InteractiveSession()

train_data = read_conll('gggggg.txt', lower_words=True)
dev_data = read_conll('123g.txt', lower_words=True)
# train_data, dev_data = train_test_split(data, test_size=0.2, random_state=42)

vocabs = {
    key: Vocab.from_lines([row[key] for row in train_data])
    for key in ['word', 'pos', 'ne']
}

def prepare_batch(data):
    keys = data[0].keys()
    return {
        key: vocabs[key].to_matrix(row[key] for row in data)
        for key in keys
    }

class SimpleModel:
    def __init__(self, name, emb_size=16, hid_size=16):  
        self.emb = L.Embedding(len(vocabs['word']), emb_size)
        self.lstm = L.Bidirectional(L.LSTM(hid_size, return_sequences=True))
        self.logits = L.Dense(len(vocabs['ne']))
    
    def __call__(self, input_ix):
        embeddings = self.emb(input_ix)
        bdlstm = self.lstm(embeddings)
        ner_logits = self.logits(bdlstm)        
        return {'ne': ner_logits}
    
model = SimpleModel('mod1')
sess.run(tf.global_variables_initializer())

class trainer:
    """ A bunch of tensorflow operations used for model training """
    
    ph = {
        'word': tf.placeholder('int32', [None, None], name='input_tokens'),
        'ne': tf.placeholder('int32', [None, None], name='named_entities'),
    }

    logits = model(ph['word'])
    mask = infer_mask(ph['word'])
    
    loss = -tf.nn.log_softmax(logits['ne'], -1) * tf.one_hot(ph['ne'], len(vocabs['ne']))
    loss = tf.reduce_sum(loss * mask[:, :, None]) / tf.reduce_sum(mask)

    step = tf.train.AdamOptimizer().minimize(loss)

def iterate_minibatches(data, batch_size=128, shuffle=True, cycle=False, max_batches=None):
    indices = np.arange(len(data))
    total_batches = 0
    while True:
        if shuffle: indices = np.random.permutation(indices)
        for start_i in range(0, len(data), batch_size):
            batch_ix = indices[start_i: start_i + batch_size]
            yield prepare_batch(data[batch_ix])
            total_batches += 1
            if max_batches and total_batches >= max_batches:
                return
        if not cycle: break
            

def compute_error_rate(trainer, data, batch_size=128, key='ne'):
    numerator = denominator = 0.0
    for batch in iterate_minibatches(data, batch_size, shuffle=False, cycle=False):
        batch_ne_logits, batch_mask = sess.run([trainer.logits[key], trainer.mask], 
                                               {trainer.ph['word']: batch['word']})
        numerator += np.sum((batch[key] == batch_ne_logits.argmax(-1)) * batch_mask)
        denominator += batch_mask.sum()
    return (1.0 - numerator / denominator) * 100

def decode_greedy(trainer, data, vocabs, batch_size=128, key='ne'):
    result = []
    for batch in iterate_minibatches(data, batch_size, shuffle=False, cycle=False):
        batch_logits = sess.run(trainer.logits[key], 
                                {trainer.ph['word']: batch['word']})
        result.extend(vocabs[key].to_lines(batch_logits.argmax(-1)))
    return result

results = list()
def compute_stats(trainer, data, vocabs, batch_size=128, key='ne', verbose=False):
    pred_seqs = decode_greedy(trainer, data, vocabs, batch_size, key)
    true_seqs = [r[key] for r in data]
    results.append((pred_seqs, true_seqs))
    precision, recall, f1 = evaluate(true_seqs, pred_seqs, verbose)
    return precision, recall, f1
    
class StatsHistory:
    def __init__(self):
        self.precision = []
        self.recall = []
        self.f1 = []

eval_every = 50

loss_history = []
dev_stats_history = StatsHistory()
indomain_stats_history = StatsHistory()
outdomain_stats_history = StatsHistory()

sess.run(tf.global_variables_initializer())
saver = tf.train.Saver()
''' 
for batch in tqdm(iterate_minibatches(train_data, cycle=True, max_batches=10000)):
    loss_t, _ = sess.run([trainer.loss, trainer.step],
                         {trainer.ph[key]: batch[key] for key in trainer.ph})
    loss_history.append(loss_t)
    
    if len(loss_history) % eval_every == 0:
        precision, recall, f1 = compute_stats(trainer, dev_data, vocabs, verbose=True)
        dev_stats_history.precision.append(precision)
        dev_stats_history.recall.append(recall)
        dev_stats_history.f1.append(f1)
        clear_output(True)
        plt.figure(figsize=[12, 6])
        plt.subplot(1, 2, 1)
        plt.plot(loss_history)
        plt.title('train loss'), plt.grid()
        plt.subplot(1, 2, 2)       
        plt.plot(np.arange(1, len(dev_stats_history.f1) + 1) * eval_every, dev_stats_history.f1, label="dev f1")
        plt.legend()
        plt.title('dev stats %'), plt.grid()
        plt.show()
'''
# Out:
# ' \nfor batch in tqdm(iterate_minibatches(train_data, cycle=True, max_batches=10000)):\n    loss_t, _ = sess.run([trainer.loss, trainer.step],\n                         {trainer.ph[key]: batch[key] for key in trainer.ph})\n    loss_history.append(loss_t)\n    \n    if len(loss_history) % eval_every == 0:\n        precision, recall, f1 = compute_stats(trainer, dev_data, vocabs, verbose=True)\n        dev_stats_history.precision.append(precision)\n        dev_stats_history.recall.append(recall)\n        dev_stats_history.f1.append(f1)\n        clear_output(True)\n        plt.figure(figsize=[12, 6])\n        plt.subplot(1, 2, 1)\n        plt.plot(loss_history)\n        plt.title(\'train loss\'), plt.grid()\n        plt.subplot(1, 2, 2)       \n        plt.plot(np.arange(1, len(dev_stats_history.f1) + 1) * eval_every, dev_stats_history.f1, label="dev f1")\n        plt.legend()\n        plt.title(\'dev stats %\'), plt.grid()\n        plt.show()\n'

# %%
saver = tf.train.Saver()
saver.restore(sess, "model/model2.ckpt")
# Out:
# INFO:tensorflow:Restoring parameters from model/model2.ckpt

# %% [markdown]
# Получение запроса из NERa

# %%
def Extractor(queries):
    
    def NER(data):
    
        def prepare_for_predict(sent):
            result = dict()
            result['word'] = sent
            result['ne'] = ' '.join(['O'] * len(sent.split()))
            result['pos'] = ' '.join(['O'] * len(sent.split()))
            return np.array([result])
    
        def get_ner(p):
            result = list()
            for batch in iterate_minibatches(p, 1, shuffle=False, cycle=False):
                    batch_logits = sess.run(trainer.logits['ne'], 
                                            {trainer.ph['word']: batch['word']})
                    result.extend(vocabs['ne'].to_lines(batch_logits.argmax(-1)))
            return result

        data_format = prepare_for_predict(data)
        return get_ner(data_format)  
    
    er = list()
    for q in queries:
        er.append((q, NER(q)))
    l = list()
    for queri in er:
        items = dict()
        items['Offer_type'] = 0
        items['Attributes'] = ''
        items['Price_from'] = 0
        items['Item'] = list()
        items['Price_to'] = list()
        items['Cashback'] = list()
        items['Sale'] = list()
        for i, name in enumerate(queri[1][0].split()):
            if name == 'I-Name':
                items['Item'].append(queri[0].split()[i])
                continue
            if name == 'I-PRICE':
                try:
                    items['Price_to'].append(float(queri[0].split()[i]))
                except:
                    pass
                continue
            if name == 'I-CB':
                try:
                    items['Cashback'].append(0.5)
                except:
                    pass
                continue
            if name == 'I-SL':
                try:
                    items['Sale'].append(0.5)
                except:
                    pass
                continue
            if name == 'I-PRICE':
                try:
                    items['Price_to'].append(float(queri[0].split()[i]))
                except:
                    pass
                continue
            if name == 'I-CB_V':
                try:
                    if float(queri[0].split()[i]) < 100:
                        items['Cashback'].append(float(queri[0].split()[i]))
                    else:
                        items['Price_to'].append(float(queri[0].split()[i]))
                except:
                    pass
                continue
            if name == 'I-SL_V':
                try:
                    if float(queri[0].split()[i]) < 100:
                        items['Sale'].append(float(queri[0].split()[i]))
                    else:
                        items['Price_to'].append(float(queri[0].split()[i]))
                except:
                    pass
                continue
        if items['Sale']:
            max_sale = max(items['Sale'])
            items['Sale'].clear()
            items['Sale'] = max_sale
        else: items['Sale'] = 0
        if items['Cashback']:
            max_cb = max(items['Cashback'])
            items['Cashback'].clear()
            items['Cashback'] = max_cb
        else: items['Cashback'] = 0
        if items['Price_to']:
            max_pr = max(items['Price_to'])
            items['Price_to'].clear()
            items['Price_to'] = max_pr        
        else: items['Price_to'] = 9999999
        l.append(items)
    return l

# %% [markdown]
# # Поисковик

# %%
class Ranker(metaclass=abc.ABCMeta):
    @abc.abstractmethod
    def rank(self, search_form: t.Dict[str, t.Any]) -> t.List[t.Dict[str, t.Any]]:
        pass

# %%
class ElasticsearchRanker(Ranker):
    __DEFAULT_INDEX = 'offer_search'
    __DEFAULT_DOC_TYPE = 'product'

    __SEARCH_QUERY_ITEM = {
        'query': {
            'bool': {
                'must': [
                    {
                        'fuzzy': {
                            'Item': {
                                'value': None,
                                'prefix_length': 0,
                            }
                        },
                    },
                ],
                'should': [
                    {
                        'multi_match': {
                                'query': None,
                                'fields': ['Item', 'Attributes', 'Advert_text'],
                                'type': 'best_fields'
                            }
                    },
                ],
                'filter': [
                    {
                        'range': {
                            'Price': {
                                'gte': None,
                                'lte': None,
                            }
                        },
                    },
                    {
                        'range': {
                            'Cashback': {
                                'gte': None,
                            }
                        },
                    },
                    {
                        'range': {
                            'Offer_type': {
                                'gte' : None,
                                'lte' : None,
                            }
                        }
                    },
                ]
            },
        },
        'size': 10000,
    }


    __SEARCH_QUERY_ATTRIBUTES = {
        'query': {
            'bool': {
                'should': [
                    {
                        'multi_match': {
                                'query': None,
                                'fields': ['Item', 'Attributes', 'Advert_text'],
                                'type': 'best_fields'
                            }
                    },
                ],
                'filter': [
                    {
                        'range': {
                            'Price': {
                                'gte': None,
                                'lte': None,
                            }
                        },
                    },
                    {
                        'range': {
                            'Cashback': {
                                'gte': None,
                            }
                        },
                    },
                    {
                        'range': {
                            'Offer_type': {
                                'gte' : None,
                                'lte' : None,
                            }
                        }
                    },
                ]
            },
        },
        'size': 10000,
    }

    __KEYS_TO_SET_ITEM = ('query', 'bool', 'must', 0, 'fuzzy', 'Item', 'value')
    __KEYS_TO_SET_ATTRIBUTES = ('query', 'bool', 'should', 0, 'multi_match', 'query')
    __KEYS_TO_SET_PRICE_FROM = ('query', 'bool', 'filter', 0, 'range', 'Price', 'gte')
    __KEYS_TO_SET_PRICE_TO = ('query', 'bool', 'filter', 0, 'range', 'Price', 'lte')
    __KEYS_TO_SET_CASHBACK = ('query', 'bool', 'filter', 1, 'range', 'Cashback', 'gte')
    __KEYS_TO_SET_OFFER_TYPE_FROM = ('query', 'bool', 'filter', 2, 'range', 'Offer_type', 'gte')
    __KEYS_TO_SET_OFFER_TYPE_TO = ('query', 'bool', 'filter', 2, 'range', 'Offer_type', 'lte')

    def __init__(
        self, 
        es_host: str = 'localhost', 
        es_port: int = 9200,
        index: str = __DEFAULT_INDEX,
        doc_type: str = __DEFAULT_DOC_TYPE,
        preset: t.Optional[t.List[t.Dict[str, t.Any]]] = None,
    ) -> None:
        self.__elasticsearch = Elasticsearch([{
            'host': es_host,
            'port': es_port,
        }])

        if not self.__elasticsearch.ping():
            raise ValueError(f"Can not connect to Elasticsearch: {es_host}:{es_port}")

        self.__index = index
        self.__doc_type = doc_type

        if preset is not None:
            self.__preset(preset)

    @overrides
    def rank(self, search_form: t.Dict[str, t.Any]) -> t.List[t.Dict[str, t.Any]]:
        search_result = self.__elasticsearch.search(
            index=self.__index,
            doc_type=self.__doc_type,
            body=self.__build_search_query(search_form),
        )

        return [record['_source'] for record in search_result['hits']['hits']]

    def __preset(self, preset: t.List[t.Dict[str, t.Any]]) -> t.NoReturn:
        for record in preset:
            self.__elasticsearch.index(
                index=self.__index, 
                doc_type=self.__doc_type, 
                body=record,
            )

    @classmethod
    def __build_search_query(cls, search_form: t.Dict[str, t.Any]) -> t.List[t.Dict[str, t.Any]]:
        if 'Item' in search_form:
            search_query = deepcopy(cls.__SEARCH_QUERY_ITEM)

            for query_keys, query_value in (
                (cls.__KEYS_TO_SET_ITEM, search_form['Item']),
                (cls.__KEYS_TO_SET_ATTRIBUTES, search_form['Attributes']),
                (cls.__KEYS_TO_SET_PRICE_FROM, search_form['Price_from']),
                (cls.__KEYS_TO_SET_PRICE_TO, search_form['Price_to']),
                (cls.__KEYS_TO_SET_CASHBACK, search_form['Cashback']),
                (cls.__KEYS_TO_SET_OFFER_TYPE_FROM, search_form['Offer_type_from']),
                (cls.__KEYS_TO_SET_OFFER_TYPE_TO, search_form['Offer_type_to']),
            ):
                cls.__set_query_value(search_query, query_keys, query_value)
        else:
            search_query = deepcopy(cls.__SEARCH_QUERY_ATTRIBUTES)

            for query_keys, query_value in (
                (cls.__KEYS_TO_SET_ATTRIBUTES, search_form['Attributes']),
                (cls.__KEYS_TO_SET_PRICE_FROM, search_form['Price_from']),
                (cls.__KEYS_TO_SET_PRICE_TO, search_form['Price_to']),
                (cls.__KEYS_TO_SET_CASHBACK, search_form['Cashback']),
                (cls.__KEYS_TO_SET_OFFER_TYPE_FROM, search_form['Offer_type_from']),
                (cls.__KEYS_TO_SET_OFFER_TYPE_TO, search_form['Offer_type_to']),
            ):
                cls.__set_query_value(search_query, query_keys, query_value)

        return search_query

    @staticmethod
    def __set_query_value(query: t.Dict[str, t.Any], keys: t.Tuple[str], value: t.Any) -> t.NoReturn:
        container = query

        # try to come to penultimate ("last but one") contrainer, so use keys without its tail
        # it is nessaccary because otherwise we will lose reference to last container and will
        # not be able to set new value
        keys_to_penultimate_container = keys[:-1]
        last_key = keys[-1]

        for key in keys_to_penultimate_container:
            container = itemgetter(key)(container)

        container[last_key] = value

# %%
logger = logging.getLogger('Searcher')


class Searcher:
    def __init__(
        self,
        extractor: Extractor,
        ranker: Ranker,
        classifier: IntentClassifier
    ) -> None:
        self.__extractor = extractor
        self.__classifier = classifier
        self.__ranker = ranker

    def search(self, texts: t.List[str], n_top: int = 5) -> t.List[t.Dict[str, t.Any]]:
        
        forms = self.__extractor(texts)
        queries = []
        for i,form in enumerate(forms):
            
            if len(form['Item']) > 1: 
                scores = np.zeros((len(form['Item']),2))
                for i, word in enumerate(form['Item']):
                    scores[i] = classifier.classify(word)
                item_index = scores[:,1].argmax(axis = 0)
                scores[item_index][1] = -2
                atribute_index = scores[:,1].argmax(axis = 0)
                

                
                index = np.ones((len(form['Item'])),dtype=np.bool)
                index[item_index] = 0
#                 Отбор одного или всех оставшихся атрибутов, Раскоментить нужную опцию.
                form['Attributes'] = ' '.join(np.array(form['Item'])[index])                
#                 form['Attributes'] = form['Item'][atribute_index]
                form['Item'] = form['Item'][item_index]
                
            if len(form['Item']) == 1:
                form['Item'] = form['Item'][0]
                        
            if 0 == len(form['Item']):
                form.pop('Item')
                if 0 == len(form['Attributes']):
                    form['Attributes'] = texts[i]
            form['Offer_type_from'] = form['Offer_type']
            form['Offer_type_to'] = form['Offer_type']

            logger.debug(f"slots:\t{json.dumps(form, ensure_ascii=False, indent=4)}")
           
            print (form)
            
            if 0 == form['Offer_type'] and form['Cashback'] > 0:
                ranking = self.__ranker.rank(form)
                if 0 == len(ranking):
                    form['Cashback'] = 0
                    ranking = self.__ranker.rank(form)
            elif 1 == form['Offer_type']:
                ranking = self.__ranker.rank(form)
            else:
                form['Offer_type_from'] = 0
                form['Offer_type_to'] = 1
                ranking = self.__ranker.rank(form)

            if 0 == len(ranking):
                form['Offer_type_from'] = 0
                form['Offer_type_to'] = 1
                ranking = self.__ranker.rank(form)

            offers = self.__group_product_ranking_by_offer(ranking)
            
            queries.append(offers[:n_top])
            
#           Замедление для elastic, без остановок сервер не успевает обрабатывать,
#           можно поиграться с задержкой.

            time.sleep(2)
        return queries

    @staticmethod
    def __group_product_ranking_by_offer(
        ranking: t.List[t.Dict[str, t.Any]],
        n_top: int = 3,
    ) -> t.List[t.Dict[str, t.Any]]:
        offer_names = set()
        offers = []
        for offer, products in it.groupby(ranking, key=lambda product: product['Offer']):
            if offer in offer_names:
                continue

            new_products = []
            for product in products:
                product.pop('Offer')
                web = product.pop('Web')
                cashback = product.pop('Cashback')
                period = product.pop('Period')
                offer_type = product.pop('Offer_type')
                advert_text = product.pop('Advert_text')
                new_products.append(product)
            products = new_products

            offer_names.add(offer)
            offers.append({
                'offer': {
                    'offer': offer,
                    'web': web,
                    'cashback': cashback,
                    'period': period,
                    'offer_type': offer_type,
                    'advert_text': advert_text,
                },
                'products': list(products)[:n_top],  # here we can return shorten information about the 
                                                     # products or only links to them
            })

        return offers

# %%
def create_ranker(
    elasticsearch_host: str = 'localhost',
    elasticsearch_port: int = 9200,
    preset_path: t.Optional[Path] = Path('./resources/ranking/preset_small.json'),
) -> Ranker:
    preset = None

    if preset_path is not None:
        with preset_path.open('r') as preset_file:
            preset: t.List[t.Dict[str, t.Any]] = json.load(preset_file)

    return ElasticsearchRanker(
        elasticsearch_host,
        elasticsearch_port,
        preset=preset,
    )

def __create_searcher() -> Searcher:
    return Searcher(
        create_extractor(),
        create_ranker(
            CONFIGURATION['RANKER_ELASTICSEARCH_HOST'],
            CONFIGURATION['RANKER_ELASTICSEARCH_PORT'],
        ),
    )

# %%
classifier = IntentClassifier()

# %%
#Удалить параметр в create_ranker при первом запуске.
searcher = Searcher(
    Extractor, 
    create_ranker(preset_path = None),
    classifier    
)

# %%
#Чтение запросов
queries = list()
with open('query_text_final.txt') as f:
    for line in f:
        queries.append(line.replace('\n', ''))
queries = preprocessing(queries)

# %%
results = searcher.search(queries)
# Out:
# ['приобрести', 'поесть'] ['приобрести'] [ True False]
# {'Offer_type': 0, 'Attributes': 'приобрести', 'Price_from': 0, 'Item': 'поесть', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# short word
# ['туристическое', 'снаряжение', 'по'] ['снаряжение' 'по'] [False  True  True]
# {'Offer_type': 0, 'Attributes': 'снаряжение по', 'Price_from': 0, 'Item': 'туристическое', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['туристическое', 'снаряжение'] ['снаряжение'] [False  True]
# {'Offer_type': 0, 'Attributes': 'снаряжение', 'Price_from': 0, 'Item': 'туристическое', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# unknown word -  кешбеком
# ['мясо', 'кешбеком'] ['кешбеком'] [False  True]
# {'Offer_type': 0, 'Attributes': 'кешбеком', 'Price_from': 0, 'Item': 'мясо', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['приобрести', 'можно', 'беговую'] ['приобрести' 'можно'] [ True  True False]
# {'Offer_type': 0, 'Attributes': 'приобрести можно', 'Price_from': 0, 'Item': 'беговую', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['можно', 'лыжи', 'максимальным'] ['можно' 'максимальным'] [ True False  True]
# {'Offer_type': 0, 'Attributes': 'можно максимальным', 'Price_from': 0, 'Item': 'лыжи', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['заказать', 'лыжи', 'максимальным'] ['заказать' 'максимальным'] [ True False  True]
# {'Offer_type': 0, 'Attributes': 'заказать максимальным', 'Price_from': 0, 'Item': 'лыжи', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['самая', 'дешевая'] ['самая'] [ True False]
# {'Offer_type': 0, 'Attributes': 'самая', 'Price_from': 0, 'Item': 'дешевая', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['очки', 'для', 'плавания'] ['очки' 'плавания'] [ True False  True]
# {'Offer_type': 0, 'Attributes': 'очки плавания', 'Price_from': 0, 'Item': 'для', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['комплект', 'финских'] ['комплект'] [ True False]
# {'Offer_type': 0, 'Attributes': 'комплект', 'Price_from': 0, 'Item': 'финских', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# unknown word -  кроссофки
# ['кроссофки', 'для', 'бега', 'хочу'] ['кроссофки' 'для' 'хочу'] [ True  True False  True]
# {'Offer_type': 0, 'Attributes': 'кроссофки для хочу', 'Price_from': 0, 'Item': 'бега', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['очки', 'для', 'плавания'] ['очки' 'плавания'] [ True False  True]
# {'Offer_type': 0, 'Attributes': 'очки плавания', 'Price_from': 0, 'Item': 'для', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# {'Offer_type': 0, 'Attributes': '', 'Price_from': 0, 'Item': 'дартс', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# short word
# ['мороженное', 'по'] ['по'] [False  True]
# {'Offer_type': 0, 'Attributes': 'по', 'Price_from': 0, 'Item': 'мороженное', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['специальное', 'предложение', 'спорт'] ['предложение' 'спорт'] [False  True  True]
# {'Offer_type': 0, 'Attributes': 'предложение спорт', 'Price_from': 0, 'Item': 'специальное', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['конфеты', 'шоколадные'] ['шоколадные'] [False  True]
# {'Offer_type': 0, 'Attributes': 'шоколадные', 'Price_from': 0, 'Item': 'конфеты', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['велосипед', 'merida'] ['merida'] [False  True]
# {'Offer_type': 0, 'Attributes': 'merida', 'Price_from': 0, 'Item': 'велосипед', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# unknown word -  коровьесвадебный
# ['молоко', 'коровьесвадебный'] ['коровьесвадебный'] [False  True]
# {'Offer_type': 0, 'Attributes': 'коровьесвадебный', 'Price_from': 0, 'Item': 'молоко', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['пироги', 'доставкой'] ['доставкой'] [False  True]
# {'Offer_type': 0, 'Attributes': 'доставкой', 'Price_from': 0, 'Item': 'пироги', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['фигурный', 'коньки'] ['фигурный'] [ True False]
# {'Offer_type': 0, 'Attributes': 'фигурный', 'Price_from': 0, 'Item': 'коньки', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# {'Offer_type': 0, 'Attributes': '', 'Price_from': 0, 'Item': 'велосипед', 'Price_to': 20000.0, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# short word
# ['доставка', 'еды', 'из'] ['доставка' 'из'] [ True False  True]
# {'Offer_type': 0, 'Attributes': 'доставка из', 'Price_from': 0, 'Item': 'еды', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# {'Offer_type': 0, 'Attributes': 'со скидкой макдональдс ', 'Price_from': 0, 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0.5, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['приобрести', 'мороженное'] ['приобрести'] [ True False]
# {'Offer_type': 0, 'Attributes': 'приобрести', 'Price_from': 0, 'Item': 'мороженное', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['приобрести', 'сноуборд'] ['сноуборд'] [False  True]
# {'Offer_type': 0, 'Attributes': 'сноуборд', 'Price_from': 0, 'Item': 'приобрести', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0.5, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['комплект', 'финских'] ['комплект'] [ True False]
# {'Offer_type': 0, 'Attributes': 'комплект', 'Price_from': 0, 'Item': 'финских', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['доставка', 'еды'] ['доставка'] [ True False]
# {'Offer_type': 0, 'Attributes': 'доставка', 'Price_from': 0, 'Item': 'еды', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['хоккейное', 'снаряжение', 'заказать'] ['снаряжение' 'заказать'] [False  True  True]
# {'Offer_type': 0, 'Attributes': 'снаряжение заказать', 'Price_from': 0, 'Item': 'хоккейное', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# unknown word -  кешбеком
# ['хоккейное', 'снаряжение', 'кешбеком'] ['снаряжение' 'кешбеком'] [False  True  True]
# {'Offer_type': 0, 'Attributes': 'снаряжение кешбеком', 'Price_from': 0, 'Item': 'хоккейное', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# short word
# ['доставка', 'еды', 'из'] ['доставка' 'из'] [ True False  True]
# {'Offer_type': 0, 'Attributes': 'доставка из', 'Price_from': 0, 'Item': 'еды', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['фигурный', 'коньки', 'можно'] ['фигурный' 'можно'] [ True False  True]
# {'Offer_type': 0, 'Attributes': 'фигурный можно', 'Price_from': 0, 'Item': 'коньки', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['беговую', 'дорожку'] ['дорожку'] [False  True]
# {'Offer_type': 0, 'Attributes': 'дорожку', 'Price_from': 0, 'Item': 'беговую', 'Price_to': 20000.0, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['хоккейное', 'снаряжение', 'максимальным'] ['снаряжение' 'максимальным'] [False  True  True]
# {'Offer_type': 0, 'Attributes': 'снаряжение максимальным', 'Price_from': 0, 'Item': 'хоккейное', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# short word
# ['по', 'акции', 'курицу'] ['по' 'акции'] [ True  True False]
# {'Offer_type': 0, 'Attributes': 'по акции', 'Price_from': 0, 'Item': 'курицу', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['приобрести', 'фрукты'] ['приобрести'] [ True False]
# {'Offer_type': 0, 'Attributes': 'приобрести', 'Price_from': 0, 'Item': 'фрукты', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# unknown word -  кроссофки
# ['беговые', 'кроссофки', 'для', 'бега'] ['кроссофки' 'для' 'бега'] [False  True  True  True]
# {'Offer_type': 0, 'Attributes': 'кроссофки для бега', 'Price_from': 0, 'Item': 'беговые', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['ананасы', 'заказать'] ['заказать'] [False  True]
# {'Offer_type': 0, 'Attributes': 'заказать', 'Price_from': 0, 'Item': 'ананасы', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0.5, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['хочу', 'скушать', 'грузинская'] ['хочу' 'грузинская'] [ True False  True]
# {'Offer_type': 0, 'Attributes': 'хочу грузинская', 'Price_from': 0, 'Item': 'скушать', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# unknown word -  тайская
# ['тайская', 'еда'] ['тайская'] [ True False]
# {'Offer_type': 0, 'Attributes': 'тайская', 'Price_from': 0, 'Item': 'еда', 'Price_to': 500.0, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['самая', 'дешевая'] ['самая'] [ True False]
# {'Offer_type': 0, 'Attributes': 'самая', 'Price_from': 0, 'Item': 'дешевая', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['ресторан', 'грузинской', 'кухни'] ['ресторан' 'грузинской'] [ True  True False]
# {'Offer_type': 0, 'Attributes': 'ресторан грузинской', 'Price_from': 0, 'Item': 'кухни', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['можно', 'поесть'] ['можно'] [ True False]
# {'Offer_type': 0, 'Attributes': 'можно', 'Price_from': 0, 'Item': 'поесть', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['можно', 'перчатки', 'для', 'велоспорта'] ['можно' 'перчатки' 'для'] [ True  True  True False]
# {'Offer_type': 0, 'Attributes': 'можно перчатки для', 'Price_from': 0, 'Item': 'велоспорта', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['велосипед', 'merida', 'заказать'] ['merida' 'заказать'] [False  True  True]
# {'Offer_type': 0, 'Attributes': 'merida заказать', 'Price_from': 0, 'Item': 'велосипед', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['дешевле', 'молоко'] ['дешевле'] [ True False]
# {'Offer_type': 0, 'Attributes': 'дешевле', 'Price_from': 0, 'Item': 'молоко', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['приобрести', 'грузинская'] ['грузинская'] [False  True]
# {'Offer_type': 0, 'Attributes': 'грузинская', 'Price_from': 0, 'Item': 'приобрести', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['азиатская', 'кухня', 'доставкой'] ['азиатская' 'кухня'] [ True  True False]
# {'Offer_type': 0, 'Attributes': 'азиатская кухня', 'Price_from': 0, 'Item': 'доставкой', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['вкусная', 'еда'] ['вкусная'] [ True False]
# {'Offer_type': 0, 'Attributes': 'вкусная', 'Price_from': 0, 'Item': 'еда', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['доставка', 'еды'] ['доставка'] [ True False]
# {'Offer_type': 0, 'Attributes': 'доставка', 'Price_from': 0, 'Item': 'еды', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# unknown word -  велотренажеры
# ['велотренажеры', 'самой', 'большой'] ['велотренажеры' 'самой'] [ True  True False]
# {'Offer_type': 0, 'Attributes': 'велотренажеры самой', 'Price_from': 0, 'Item': 'большой', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0.5, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['приобрести', 'яблочный', 'пирог'] ['приобрести' 'пирог'] [ True False  True]
# {'Offer_type': 0, 'Attributes': 'приобрести пирог', 'Price_from': 0, 'Item': 'яблочный', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# unknown word -  тайская
# ['тайская', 'еда', 'приобрести'] ['тайская' 'приобрести'] [ True False  True]
# {'Offer_type': 0, 'Attributes': 'тайская приобрести', 'Price_from': 0, 'Item': 'еда', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# short word
# ['доставка', 'пиццы', 'по', 'дом'] ['доставка' 'по' 'дом'] [ True False  True  True]
# {'Offer_type': 0, 'Attributes': 'доставка по дом', 'Price_from': 0, 'Item': 'пиццы', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0.5, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['дешево', 'курицу'] ['дешево'] [ True False]
# {'Offer_type': 0, 'Attributes': 'дешево', 'Price_from': 0, 'Item': 'курицу', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['хочу', 'скушать', 'яблочный'] ['хочу' 'скушать'] [ True  True False]
# {'Offer_type': 0, 'Attributes': 'хочу скушать', 'Price_from': 0, 'Item': 'яблочный', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['лыжные', 'палки', 'хочу'] ['палки' 'хочу'] [False  True  True]
# {'Offer_type': 0, 'Attributes': 'палки хочу', 'Price_from': 0, 'Item': 'лыжные', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['самая', 'дешевая'] ['самая'] [ True False]
# {'Offer_type': 0, 'Attributes': 'самая', 'Price_from': 0, 'Item': 'дешевая', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# {'Offer_type': 0, 'Attributes': '', 'Price_from': 0, 'Item': 'приобрести', 'Price_to': 9999999, 'Cashback': 10.0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# {'Offer_type': 0, 'Attributes': '', 'Price_from': 0, 'Item': 'яйца', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0.5, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['велосипед', 'горный'] ['горный'] [False  True]
# {'Offer_type': 0, 'Attributes': 'горный', 'Price_from': 0, 'Item': 'велосипед', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# short word
# ['лыжи', 'по'] ['по'] [False  True]
# {'Offer_type': 0, 'Attributes': 'по', 'Price_from': 0, 'Item': 'лыжи', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# unknown word -  тайская
# ['приобрести', 'тайская', 'еда'] ['приобрести' 'тайская'] [ True  True False]
# {'Offer_type': 0, 'Attributes': 'приобрести тайская', 'Price_from': 0, 'Item': 'еда', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# unknown word -  2015
# ['велосипед', 'горный', '2015'] ['горный' '2015'] [False  True  True]
# {'Offer_type': 0, 'Attributes': 'горный 2015', 'Price_from': 0, 'Item': 'велосипед', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0.5, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['спецпредложение', 'еду'] ['спецпредложение'] [ True False]
# {'Offer_type': 0, 'Attributes': 'спецпредложение', 'Price_from': 0, 'Item': 'еду', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['доставка', 'еды'] ['доставка'] [ True False]
# {'Offer_type': 0, 'Attributes': 'доставка', 'Price_from': 0, 'Item': 'еды', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['гантели', 'addidas'] ['addidas'] [False  True]
# {'Offer_type': 0, 'Attributes': 'addidas', 'Price_from': 0, 'Item': 'гантели', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['очень', 'дешево', 'курицу'] ['очень' 'дешево'] [ True  True False]
# {'Offer_type': 0, 'Attributes': 'очень дешево', 'Price_from': 0, 'Item': 'курицу', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['мяч', 'для', 'регби'] ['мяч' 'для'] [ True  True False]
# {'Offer_type': 0, 'Attributes': 'мяч для', 'Price_from': 0, 'Item': 'регби', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# unknown word -  тайская
# ['тайская', 'еда'] ['тайская'] [ True False]
# {'Offer_type': 0, 'Attributes': 'тайская', 'Price_from': 0, 'Item': 'еда', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['быстрая', 'доставка'] ['быстрая'] [ True False]
# {'Offer_type': 0, 'Attributes': 'быстрая', 'Price_from': 0, 'Item': 'доставка', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['велосипед', 'merida'] ['merida'] [False  True]
# {'Offer_type': 0, 'Attributes': 'merida', 'Price_from': 0, 'Item': 'велосипед', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['хочу', 'свежие', 'фрукты'] ['хочу' 'свежие'] [ True  True False]
# {'Offer_type': 0, 'Attributes': 'хочу свежие', 'Price_from': 0, 'Item': 'фрукты', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['нужны', 'теннисные'] ['нужны'] [ True False]
# {'Offer_type': 0, 'Attributes': 'нужны', 'Price_from': 0, 'Item': 'теннисные', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['мраморная', 'говядина'] ['мраморная'] [ True False]
# {'Offer_type': 0, 'Attributes': 'мраморная', 'Price_from': 0, 'Item': 'говядина', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['гантели', 'можно'] ['можно'] [False  True]
# {'Offer_type': 0, 'Attributes': 'можно', 'Price_from': 0, 'Item': 'гантели', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# {'Offer_type': 0, 'Attributes': '', 'Price_from': 0, 'Item': 'пиццу', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0.5, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['доставка', 'гантелей', 'дом'] ['доставка' 'дом'] [ True False  True]
# {'Offer_type': 0, 'Attributes': 'доставка дом', 'Price_from': 0, 'Item': 'гантелей', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['мяч', 'волейбольный', 'дешевле'] ['мяч' 'дешевле'] [ True False  True]
# {'Offer_type': 0, 'Attributes': 'мяч дешевле', 'Price_from': 0, 'Item': 'волейбольный', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['лыжную', 'куртку'] ['куртку'] [False  True]
# {'Offer_type': 0, 'Attributes': 'куртку', 'Price_from': 0, 'Item': 'лыжную', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['самая', 'быстрая'] ['быстрая'] [False  True]
# {'Offer_type': 0, 'Attributes': 'быстрая', 'Price_from': 0, 'Item': 'самая', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['заказать', 'мороженное'] ['заказать'] [ True False]
# {'Offer_type': 0, 'Attributes': 'заказать', 'Price_from': 0, 'Item': 'мороженное', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['фрукты', 'хочу', 'максимальным'] ['хочу' 'максимальным'] [False  True  True]
# {'Offer_type': 0, 'Attributes': 'хочу максимальным', 'Price_from': 0, 'Item': 'фрукты', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# unknown word -  тайская
# ['тайская', 'еда'] ['тайская'] [ True False]
# {'Offer_type': 0, 'Attributes': 'тайская', 'Price_from': 0, 'Item': 'еда', 'Price_to': 500.0, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# {'Offer_type': 0, 'Attributes': '', 'Price_from': 0, 'Item': 'велосипед', 'Price_to': 20000.0, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['максимальная', 'горный', 'велосипед'] ['максимальная' 'горный'] [ True  True False]
# {'Offer_type': 0, 'Attributes': 'максимальная горный', 'Price_from': 0, 'Item': 'велосипед', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0.5, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['горный', 'велосипед'] ['горный'] [ True False]
# {'Offer_type': 0, 'Attributes': 'горный', 'Price_from': 0, 'Item': 'велосипед', 'Price_to': 10000.0, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['хочу', 'хоккейную', 'клюшку'] ['хочу' 'клюшку'] [ True False  True]
# {'Offer_type': 0, 'Attributes': 'хочу клюшку', 'Price_from': 0, 'Item': 'хоккейную', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['хоккейное', 'снаряжение', 'приобрести', 'максимальным'] ['снаряжение' 'приобрести' 'максимальным'] [False  True  True  True]
# {'Offer_type': 0, 'Attributes': 'снаряжение приобрести максимальным', 'Price_from': 0, 'Item': 'хоккейное', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# unknown word -  вок
# ['вок', 'можно'] ['вок'] [ True False]
# {'Offer_type': 0, 'Attributes': 'вок', 'Price_from': 0, 'Item': 'можно', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0.5, 'Offer_type_from': 0, 'Offer_type_to': 0}
# unknown word -  2015
# ['велосипед', 'горный', '2015'] ['горный' '2015'] [False  True  True]
# {'Offer_type': 0, 'Attributes': 'горный 2015', 'Price_from': 0, 'Item': 'велосипед', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['максимальная', 'горный', 'велосипед'] ['максимальная' 'горный'] [ True  True False]
# {'Offer_type': 0, 'Attributes': 'максимальная горный', 'Price_from': 0, 'Item': 'велосипед', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0.5, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['пироги', 'доставкой'] ['доставкой'] [False  True]
# {'Offer_type': 0, 'Attributes': 'доставкой', 'Price_from': 0, 'Item': 'пироги', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['самые', 'выгодные', 'цены', 'велосипед', 'горный'] ['самые' 'выгодные' 'цены' 'горный'] [ True  True  True False  True]
# {'Offer_type': 0, 'Attributes': 'самые выгодные цены горный', 'Price_from': 0, 'Item': 'велосипед', 'Price_to': 2015.0, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['суши', 'хочу'] ['хочу'] [False  True]
# {'Offer_type': 0, 'Attributes': 'хочу', 'Price_from': 0, 'Item': 'суши', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# unknown word -  тайская
# ['тайская', 'еда', 'доставкой'] ['тайская' 'доставкой'] [ True False  True]
# {'Offer_type': 0, 'Attributes': 'тайская доставкой', 'Price_from': 0, 'Item': 'еда', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# unknown word -  пилатеса
# ['беговые', 'мяч', 'для', 'пилатеса', 'приобрести'] ['мяч' 'для' 'пилатеса' 'приобрести'] [False  True  True  True  True]
# {'Offer_type': 0, 'Attributes': 'мяч для пилатеса приобрести', 'Price_from': 0, 'Item': 'беговые', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0.5, 'Offer_type_from': 0, 'Offer_type_to': 0}
# unknown word -  вок
# ['вок', 'домой'] ['вок'] [ True False]
# {'Offer_type': 0, 'Attributes': 'вок', 'Price_from': 0, 'Item': 'домой', 'Price_to': 500.0, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['можно', 'грузинская'] ['можно'] [ True False]
# {'Offer_type': 0, 'Attributes': 'можно', 'Price_from': 0, 'Item': 'грузинская', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['мясо', 'очень'] ['очень'] [False  True]
# {'Offer_type': 0, 'Attributes': 'очень', 'Price_from': 0, 'Item': 'мясо', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['скушать', 'яблочный'] ['скушать'] [ True False]
# {'Offer_type': 0, 'Attributes': 'скушать', 'Price_from': 0, 'Item': 'яблочный', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['приобрести', 'суши'] ['суши'] [False  True]
# {'Offer_type': 0, 'Attributes': 'суши', 'Price_from': 0, 'Item': 'приобрести', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['нужны', 'теннисные'] ['нужны'] [ True False]
# {'Offer_type': 0, 'Attributes': 'нужны', 'Price_from': 0, 'Item': 'теннисные', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['хоккейное', 'снаряжение', 'хочу'] ['снаряжение' 'хочу'] [False  True  True]
# {'Offer_type': 0, 'Attributes': 'снаряжение хочу', 'Price_from': 0, 'Item': 'хоккейное', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['мяч', 'волейбольный'] ['мяч'] [ True False]
# {'Offer_type': 0, 'Attributes': 'мяч', 'Price_from': 0, 'Item': 'волейбольный', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['футбольный', 'мяч'] ['мяч'] [False  True]
# {'Offer_type': 0, 'Attributes': 'мяч', 'Price_from': 0, 'Item': 'футбольный', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['поесть', 'рядом'] ['рядом'] [False  True]
# {'Offer_type': 0, 'Attributes': 'рядом', 'Price_from': 0, 'Item': 'поесть', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# unknown word -  коровьесвадебный
# ['молоко', 'коровьесвадебный', 'торт', 'хочу'] ['коровьесвадебный' 'торт' 'хочу'] [False  True  True  True]
# {'Offer_type': 0, 'Attributes': 'коровьесвадебный торт хочу', 'Price_from': 0, 'Item': 'молоко', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['хочу', 'можно'] ['можно'] [False  True]
# {'Offer_type': 0, 'Attributes': 'можно', 'Price_from': 0, 'Item': 'хочу', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['спецпредложение', 'молоко'] ['спецпредложение'] [ True False]
# {'Offer_type': 0, 'Attributes': 'спецпредложение', 'Price_from': 0, 'Item': 'молоко', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# {'Offer_type': 0, 'Attributes': 'скидки в ресторанах', 'Price_from': 0, 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0.5, 'Offer_type_from': 0, 'Offer_type_to': 0}
# unknown word -  тренажерного
# ['одежду', 'для', 'тренажерного'] ['одежду' 'тренажерного'] [ True False  True]
# {'Offer_type': 0, 'Attributes': 'одежду тренажерного', 'Price_from': 0, 'Item': 'для', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['беговые', 'горный', 'велосипед'] ['горный' 'велосипед'] [False  True  True]
# {'Offer_type': 0, 'Attributes': 'горный велосипед', 'Price_from': 0, 'Item': 'беговые', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0.5, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['быстрая', 'доставка'] ['быстрая'] [ True False]
# {'Offer_type': 0, 'Attributes': 'быстрая', 'Price_from': 0, 'Item': 'доставка', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['приобрести', 'коньки'] ['приобрести'] [ True False]
# {'Offer_type': 0, 'Attributes': 'приобрести', 'Price_from': 0, 'Item': 'коньки', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['очки', 'для', 'плавания'] ['очки' 'плавания'] [ True False  True]
# {'Offer_type': 0, 'Attributes': 'очки плавания', 'Price_from': 0, 'Item': 'для', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['свежие', 'суши'] ['суши'] [False  True]
# {'Offer_type': 0, 'Attributes': 'суши', 'Price_from': 0, 'Item': 'свежие', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['приобрести', 'самые', 'выгодные', 'палатки'] ['приобрести' 'самые' 'выгодные'] [ True  True  True False]
# {'Offer_type': 0, 'Attributes': 'приобрести самые выгодные', 'Price_from': 0, 'Item': 'палатки', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0.5, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['боксерские', 'груши'] ['груши'] [False  True]
# {'Offer_type': 0, 'Attributes': 'груши', 'Price_from': 0, 'Item': 'боксерские', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['баскетбольное', 'кольцо', 'можно'] ['кольцо' 'можно'] [False  True  True]
# {'Offer_type': 0, 'Attributes': 'кольцо можно', 'Price_from': 0, 'Item': 'баскетбольное', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# unknown word -  пилатеса
# ['мяч', 'для', 'пилатеса'] ['для' 'пилатеса'] [False  True  True]
# {'Offer_type': 0, 'Attributes': 'для пилатеса', 'Price_from': 0, 'Item': 'мяч', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['самые', 'выгодные', 'цены', 'кроссовки'] ['самые' 'выгодные' 'цены'] [ True  True  True False]
# {'Offer_type': 0, 'Attributes': 'самые выгодные цены', 'Price_from': 0, 'Item': 'кроссовки', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['заказ', 'спортивного'] ['заказ'] [ True False]
# {'Offer_type': 0, 'Attributes': 'заказ', 'Price_from': 0, 'Item': 'спортивного', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['суши', 'хочу', 'максимальным'] ['суши' 'хочу'] [ True  True False]
# {'Offer_type': 0, 'Attributes': 'суши хочу', 'Price_from': 0, 'Item': 'максимальным', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['скушать', 'яблочный'] ['скушать'] [ True False]
# {'Offer_type': 0, 'Attributes': 'скушать', 'Price_from': 0, 'Item': 'яблочный', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['можно', 'биг'] ['биг'] [False  True]
# {'Offer_type': 0, 'Attributes': 'биг', 'Price_from': 0, 'Item': 'можно', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# {'Offer_type': 0, 'Attributes': '', 'Price_from': 0, 'Item': 'пиццу', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0.5, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['баскетбольное', 'кольцо'] ['кольцо'] [False  True]
# {'Offer_type': 0, 'Attributes': 'кольцо', 'Price_from': 0, 'Item': 'баскетбольное', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# unknown word -  коровьесвадебный
# ['молоко', 'коровьесвадебный', 'торт'] ['коровьесвадебный' 'торт'] [False  True  True]
# {'Offer_type': 0, 'Attributes': 'коровьесвадебный торт', 'Price_from': 0, 'Item': 'молоко', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['заказать', 'можно'] ['можно'] [False  True]
# {'Offer_type': 0, 'Attributes': 'можно', 'Price_from': 0, 'Item': 'заказать', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['вкусная', 'еда'] ['вкусная'] [ True False]
# {'Offer_type': 0, 'Attributes': 'вкусная', 'Price_from': 0, 'Item': 'еда', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['доставка', 'еды'] ['доставка'] [ True False]
# {'Offer_type': 0, 'Attributes': 'доставка', 'Price_from': 0, 'Item': 'еды', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['заказать', 'мясо'] ['заказать'] [ True False]
# {'Offer_type': 0, 'Attributes': 'заказать', 'Price_from': 0, 'Item': 'мясо', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0.5, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['ресторан', 'грузинской', 'кухни'] ['ресторан' 'грузинской'] [ True  True False]
# {'Offer_type': 0, 'Attributes': 'ресторан грузинской', 'Price_from': 0, 'Item': 'кухни', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# {'Offer_type': 0, 'Attributes': '', 'Price_from': 0, 'Item': 'фрукты', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['быстрая', 'доставка'] ['быстрая'] [ True False]
# {'Offer_type': 0, 'Attributes': 'быстрая', 'Price_from': 0, 'Item': 'доставка', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['недорогой', 'беговой'] ['недорогой'] [ True False]
# {'Offer_type': 0, 'Attributes': 'недорогой', 'Price_from': 0, 'Item': 'беговой', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['грузинская', 'кухня', 'хочу'] ['кухня' 'хочу'] [False  True  True]
# {'Offer_type': 0, 'Attributes': 'кухня хочу', 'Price_from': 0, 'Item': 'грузинская', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0.5, 'Offer_type_from': 0, 'Offer_type_to': 0}
# {'Offer_type': 0, 'Attributes': '', 'Price_from': 0, 'Item': 'заказать', 'Price_to': 9999999, 'Cashback': 10.0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['лыжные', 'палки', 'приобрести'] ['палки' 'приобрести'] [False  True  True]
# {'Offer_type': 0, 'Attributes': 'палки приобрести', 'Price_from': 0, 'Item': 'лыжные', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# unknown word -  дартс
# ['дартс', 'максимальной'] ['дартс'] [ True False]
# {'Offer_type': 0, 'Attributes': 'дартс', 'Price_from': 0, 'Item': 'максимальной', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0.5, 'Offer_type_from': 0, 'Offer_type_to': 0}
# unknown word -  кешбеком
# ['максимальным', 'кешбеком'] ['кешбеком'] [False  True]
# {'Offer_type': 0, 'Attributes': 'кешбеком', 'Price_from': 0, 'Item': 'максимальным', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['фрукты', 'заказать'] ['заказать'] [False  True]
# {'Offer_type': 0, 'Attributes': 'заказать', 'Price_from': 0, 'Item': 'фрукты', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0.5, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['самая', 'быстрая'] ['быстрая'] [False  True]
# {'Offer_type': 0, 'Attributes': 'быстрая', 'Price_from': 0, 'Item': 'самая', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['приобрести', 'беговые', 'лыжи'] ['приобрести' 'лыжи'] [ True False  True]
# {'Offer_type': 0, 'Attributes': 'приобрести лыжи', 'Price_from': 0, 'Item': 'беговые', 'Price_to': 15.0, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['рестораны', 'поблизости'] ['поблизости'] [False  True]
# {'Offer_type': 0, 'Attributes': 'поблизости', 'Price_from': 0, 'Item': 'рестораны', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['профессиональные', 'ролики', 'для', 'бега'] ['ролики' 'для' 'бега'] [False  True  True  True]
# {'Offer_type': 0, 'Attributes': 'ролики для бега', 'Price_from': 0, 'Item': 'профессиональные', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['беговые', 'коньки'] ['коньки'] [False  True]
# {'Offer_type': 0, 'Attributes': 'коньки', 'Price_from': 0, 'Item': 'беговые', 'Price_to': 10000.0, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# unknown word -  топовая
# ['топовая', 'теннисная', 'ракетка'] ['топовая' 'ракетка'] [ True False  True]
# {'Offer_type': 0, 'Attributes': 'топовая ракетка', 'Price_from': 0, 'Item': 'теннисная', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['доставка', 'еды'] ['доставка'] [ True False]
# {'Offer_type': 0, 'Attributes': 'доставка', 'Price_from': 0, 'Item': 'еды', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# {'Offer_type': 0, 'Attributes': '', 'Price_from': 0, 'Item': 'велосипед', 'Price_to': 20000.0, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['хочу', 'приобрести', 'фигурный'] ['хочу' 'фигурный'] [ True False  True]
# {'Offer_type': 0, 'Attributes': 'хочу фигурный', 'Price_from': 0, 'Item': 'приобрести', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# unknown word -  кроссофки
# ['хочу', 'хочу', 'кроссофки', 'для', 'бега'] ['хочу' 'хочу' 'кроссофки' 'для'] [ True  True  True  True False]
# {'Offer_type': 0, 'Attributes': 'хочу хочу кроссофки для', 'Price_from': 0, 'Item': 'бега', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['хоккейное', 'снаряжение', 'заказать'] ['снаряжение' 'заказать'] [False  True  True]
# {'Offer_type': 0, 'Attributes': 'снаряжение заказать', 'Price_from': 0, 'Item': 'хоккейное', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['приобрести', 'горные'] ['горные'] [False  True]
# {'Offer_type': 0, 'Attributes': 'горные', 'Price_from': 0, 'Item': 'приобрести', 'Price_to': 40000.0, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# unknown word -  тренажерного
# ['одежду', 'для', 'тренажерного'] ['одежду' 'тренажерного'] [ True False  True]
# {'Offer_type': 0, 'Attributes': 'одежду тренажерного', 'Price_from': 0, 'Item': 'для', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['приобрести', 'велотренажер'] ['велотренажер'] [False  True]
# {'Offer_type': 0, 'Attributes': 'велотренажер', 'Price_from': 0, 'Item': 'приобрести', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# unknown word -  тренажерного
# ['хочу', 'одежду', 'для', 'тренажерного'] ['хочу' 'одежду' 'тренажерного'] [ True  True False  True]
# {'Offer_type': 0, 'Attributes': 'хочу одежду тренажерного', 'Price_from': 0, 'Item': 'для', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['можно', 'мяч'] ['можно'] [ True False]
# {'Offer_type': 0, 'Attributes': 'можно', 'Price_from': 0, 'Item': 'мяч', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['рестораны', 'рядом', 'максимальной'] ['рядом' 'максимальной'] [False  True  True]
# {'Offer_type': 0, 'Attributes': 'рядом максимальной', 'Price_from': 0, 'Item': 'рестораны', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0.5, 'Offer_type_from': 0, 'Offer_type_to': 0}
# unknown word -  2015
# ['велосипед', 'горный', '2015', 'для'] ['горный' '2015' 'для'] [False  True  True  True]
# {'Offer_type': 0, 'Attributes': 'горный 2015 для', 'Price_from': 0, 'Item': 'велосипед', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# unknown word -  пилатеса
# ['мяч', 'для', 'пилатеса', 'для'] ['для' 'пилатеса' 'для'] [False  True  True  True]
# {'Offer_type': 0, 'Attributes': 'для пилатеса для', 'Price_from': 0, 'Item': 'мяч', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['ананасы', 'доставкой'] ['доставкой'] [False  True]
# {'Offer_type': 0, 'Attributes': 'доставкой', 'Price_from': 0, 'Item': 'ананасы', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# unknown word -  велотренажеры
# ['велотренажеры', 'самой', 'большой'] ['велотренажеры' 'самой'] [ True  True False]
# {'Offer_type': 0, 'Attributes': 'велотренажеры самой', 'Price_from': 0, 'Item': 'большой', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0.5, 'Offer_type_from': 0, 'Offer_type_to': 0}
# short word
# ['доставка', 'еды', 'из'] ['доставка' 'из'] [ True False  True]
# {'Offer_type': 0, 'Attributes': 'доставка из', 'Price_from': 0, 'Item': 'еды', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['хоккейное', 'снаряжение', 'максимальным'] ['снаряжение' 'максимальным'] [False  True  True]
# {'Offer_type': 0, 'Attributes': 'снаряжение максимальным', 'Price_from': 0, 'Item': 'хоккейное', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['комплект', 'финских'] ['комплект'] [ True False]
# {'Offer_type': 0, 'Attributes': 'комплект', 'Price_from': 0, 'Item': 'финских', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['хочу', 'беговую', 'дорожку'] ['хочу' 'дорожку'] [ True False  True]
# {'Offer_type': 0, 'Attributes': 'хочу дорожку', 'Price_from': 0, 'Item': 'беговую', 'Price_to': 20000.0, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['можно', 'хочу'] ['можно'] [ True False]
# {'Offer_type': 0, 'Attributes': 'можно', 'Price_from': 0, 'Item': 'хочу', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# short word
# ['по', 'выгодной', 'цене', 'молоко'] ['по' 'выгодной' 'цене'] [ True  True  True False]
# {'Offer_type': 0, 'Attributes': 'по выгодной цене', 'Price_from': 0, 'Item': 'молоко', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# short word
# unknown word -  партеров
# ['мяч', 'волейбольный', 'у', 'партеров'] ['мяч' 'у' 'партеров'] [ True False  True  True]
# {'Offer_type': 0, 'Attributes': 'мяч у партеров', 'Price_from': 0, 'Item': 'волейбольный', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0.5, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['комплект', 'финских'] ['комплект'] [ True False]
# {'Offer_type': 0, 'Attributes': 'комплект', 'Price_from': 0, 'Item': 'финских', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# unknown word -  вок
# short word
# ['можно', 'вок', 'у'] ['вок' 'у'] [False  True  True]
# {'Offer_type': 0, 'Attributes': 'вок у', 'Price_from': 0, 'Item': 'можно', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0.5, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['максимальной', 'курицу'] ['максимальной'] [ True False]
# {'Offer_type': 0, 'Attributes': 'максимальной', 'Price_from': 0, 'Item': 'курицу', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0.5, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['хочу', 'скушать'] ['хочу'] [ True False]
# {'Offer_type': 0, 'Attributes': 'хочу', 'Price_from': 0, 'Item': 'скушать', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['беговые', 'беговые', 'кроссовки'] ['беговые' 'кроссовки'] [False  True  True]
# {'Offer_type': 0, 'Attributes': 'беговые кроссовки', 'Price_from': 0, 'Item': 'беговые', 'Price_to': 10000.0, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# unknown word -  дартс
# ['дартс', 'для', 'бега'] ['дартс' 'для'] [ True  True False]
# {'Offer_type': 0, 'Attributes': 'дартс для', 'Price_from': 0, 'Item': 'бега', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['рестораны', 'рядом'] ['рядом'] [False  True]
# {'Offer_type': 0, 'Attributes': 'рядом', 'Price_from': 0, 'Item': 'рестораны', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['недорогой', 'беговой'] ['недорогой'] [ True False]
# {'Offer_type': 0, 'Attributes': 'недорогой', 'Price_from': 0, 'Item': 'беговой', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# unknown word -  гантелиа
# ['хочу', 'одежду', 'для', 'гантелиа'] ['хочу' 'одежду' 'гантелиа'] [ True  True False  True]
# {'Offer_type': 0, 'Attributes': 'хочу одежду гантелиа', 'Price_from': 0, 'Item': 'для', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['заказ', 'спортивного'] ['заказ'] [ True False]
# {'Offer_type': 0, 'Attributes': 'заказ', 'Price_from': 0, 'Item': 'спортивного', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['заказать', 'перчатки', 'для', 'велоспорта'] ['заказать' 'перчатки' 'для'] [ True  True  True False]
# {'Offer_type': 0, 'Attributes': 'заказать перчатки для', 'Price_from': 0, 'Item': 'велоспорта', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['можно', 'велотренажер'] ['велотренажер'] [False  True]
# {'Offer_type': 0, 'Attributes': 'велотренажер', 'Price_from': 0, 'Item': 'можно', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['приобрести', 'мяч'] ['приобрести'] [ True False]
# {'Offer_type': 0, 'Attributes': 'приобрести', 'Price_from': 0, 'Item': 'мяч', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# short word
# ['доставка', 'из', 'ресторанов'] ['доставка' 'из'] [ True  True False]
# {'Offer_type': 0, 'Attributes': 'доставка из', 'Price_from': 0, 'Item': 'ресторанов', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['азиатская', 'кухня', 'доставкой'] ['азиатская' 'кухня'] [ True  True False]
# {'Offer_type': 0, 'Attributes': 'азиатская кухня', 'Price_from': 0, 'Item': 'доставкой', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# unknown word -  кроссофки
# ['кроссофки', 'для', 'бега'] ['кроссофки' 'для'] [ True  True False]
# {'Offer_type': 0, 'Attributes': 'кроссофки для', 'Price_from': 0, 'Item': 'бега', 'Price_to': 10000.0, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# short word
# ['беговые', 'гантели', 'приобрести', 'у'] ['гантели' 'приобрести' 'у'] [False  True  True  True]
# {'Offer_type': 0, 'Attributes': 'гантели приобрести у', 'Price_from': 0, 'Item': 'беговые', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0.5, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['хочу', 'приобрести', 'фигурный'] ['хочу' 'фигурный'] [ True False  True]
# {'Offer_type': 0, 'Attributes': 'хочу фигурный', 'Price_from': 0, 'Item': 'приобрести', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# short word
# ['дешевле', 'чем', 'у'] ['чем' 'у'] [False  True  True]
# {'Offer_type': 0, 'Attributes': 'чем у', 'Price_from': 0, 'Item': 'дешевле', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['заказать', 'лыжи', 'максимальным'] ['заказать' 'максимальным'] [ True False  True]
# {'Offer_type': 0, 'Attributes': 'заказать максимальным', 'Price_from': 0, 'Item': 'лыжи', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['хочу', 'горные', 'лыжи'] ['хочу' 'горные'] [ True  True False]
# {'Offer_type': 0, 'Attributes': 'хочу горные', 'Price_from': 0, 'Item': 'лыжи', 'Price_to': 40000.0, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['недорогой', 'беговой'] ['недорогой'] [ True False]
# {'Offer_type': 0, 'Attributes': 'недорогой', 'Price_from': 0, 'Item': 'беговой', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['велосипед', 'merida', 'приобрести'] ['merida' 'приобрести'] [False  True  True]
# {'Offer_type': 0, 'Attributes': 'merida приобрести', 'Price_from': 0, 'Item': 'велосипед', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0.5, 'Offer_type_from': 0, 'Offer_type_to': 0}
# short word
# ['доставка', 'пиццы', 'по', 'дом'] ['доставка' 'по' 'дом'] [ True False  True  True]
# {'Offer_type': 0, 'Attributes': 'доставка по дом', 'Price_from': 0, 'Item': 'пиццы', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['свежие', 'суши', 'можно'] ['суши' 'можно'] [False  True  True]
# {'Offer_type': 0, 'Attributes': 'суши можно', 'Price_from': 0, 'Item': 'свежие', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['доставка', 'еды'] ['доставка'] [ True False]
# {'Offer_type': 0, 'Attributes': 'доставка', 'Price_from': 0, 'Item': 'еды', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# short word
# unknown word -  партеров
# ['поесть', 'рядом', 'у', 'партеров'] ['рядом' 'у' 'партеров'] [False  True  True  True]
# {'Offer_type': 0, 'Attributes': 'рядом у партеров', 'Price_from': 0, 'Item': 'поесть', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0.5, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['конфеты', 'шоколадные'] ['шоколадные'] [False  True]
# {'Offer_type': 0, 'Attributes': 'шоколадные', 'Price_from': 0, 'Item': 'конфеты', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['нужны', 'теннисные'] ['нужны'] [ True False]
# {'Offer_type': 0, 'Attributes': 'нужны', 'Price_from': 0, 'Item': 'теннисные', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# unknown word -  кешбеком
# ['гантели', 'хочу', 'кешбеком'] ['хочу' 'кешбеком'] [False  True  True]
# {'Offer_type': 0, 'Attributes': 'хочу кешбеком', 'Price_from': 0, 'Item': 'гантели', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# unknown word -  тайская
# ['быстрая', 'доставка', 'тайская'] ['быстрая' 'тайская'] [ True False  True]
# {'Offer_type': 0, 'Attributes': 'быстрая тайская', 'Price_from': 0, 'Item': 'доставка', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# short word
# ...
# ['биг', 'мак', 'доставкой'] ['биг' 'мак'] [ True  True False]
# {'Offer_type': 0, 'Attributes': 'биг мак', 'Price_from': 0, 'Item': 'доставкой', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['мяч', 'баскетбольный'] ['мяч'] [ True False]
# {'Offer_type': 0, 'Attributes': 'мяч', 'Price_from': 0, 'Item': 'баскетбольный', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['пироги', 'доставкой'] ['доставкой'] [False  True]
# {'Offer_type': 0, 'Attributes': 'доставкой', 'Price_from': 0, 'Item': 'пироги', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['гантели', 'для', 'бега'] ['для' 'бега'] [False  True  True]
# {'Offer_type': 0, 'Attributes': 'для бега', 'Price_from': 0, 'Item': 'гантели', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# unknown word -  пилатеса
# ['мяч', 'для', 'пилатеса'] ['для' 'пилатеса'] [False  True  True]
# {'Offer_type': 0, 'Attributes': 'для пилатеса', 'Price_from': 0, 'Item': 'мяч', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# unknown word -  тайская
# ['приобрести', 'тайская'] ['тайская'] [False  True]
# {'Offer_type': 0, 'Attributes': 'тайская', 'Price_from': 0, 'Item': 'приобрести', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['биг', 'мак', 'дешево'] ['биг' 'мак'] [ True  True False]
# {'Offer_type': 0, 'Attributes': 'биг мак', 'Price_from': 0, 'Item': 'дешево', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['доставка', 'еды'] ['доставка'] [ True False]
# {'Offer_type': 0, 'Attributes': 'доставка', 'Price_from': 0, 'Item': 'еды', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['нужны', 'боксерские', 'груши'] ['нужны' 'груши'] [ True False  True]
# {'Offer_type': 0, 'Attributes': 'нужны груши', 'Price_from': 0, 'Item': 'боксерские', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['приобрести', 'одежду', 'для'] ['приобрести' 'одежду'] [ True  True False]
# {'Offer_type': 0, 'Attributes': 'приобрести одежду', 'Price_from': 0, 'Item': 'для', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['можно', 'сладкий', 'стол'] ['можно' 'стол'] [ True False  True]
# {'Offer_type': 0, 'Attributes': 'можно стол', 'Price_from': 0, 'Item': 'сладкий', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['доставка', 'еды'] ['доставка'] [ True False]
# {'Offer_type': 0, 'Attributes': 'доставка', 'Price_from': 0, 'Item': 'еды', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['яблочный', 'пирог', 'приобрести'] ['пирог' 'приобрести'] [False  True  True]
# {'Offer_type': 0, 'Attributes': 'пирог приобрести', 'Price_from': 0, 'Item': 'яблочный', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# {'Offer_type': 0, 'Attributes': '', 'Price_from': 0, 'Item': 'велосипед', 'Price_to': 20000.0, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['пироги', 'доставкой'] ['доставкой'] [False  True]
# {'Offer_type': 0, 'Attributes': 'доставкой', 'Price_from': 0, 'Item': 'пироги', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['вкусная', 'еда'] ['вкусная'] [ True False]
# {'Offer_type': 0, 'Attributes': 'вкусная', 'Price_from': 0, 'Item': 'еда', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['пироги', 'доставкой'] ['доставкой'] [False  True]
# {'Offer_type': 0, 'Attributes': 'доставкой', 'Price_from': 0, 'Item': 'пироги', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['азиатская', 'кухня', 'доставкой'] ['азиатская' 'кухня'] [ True  True False]
# {'Offer_type': 0, 'Attributes': 'азиатская кухня', 'Price_from': 0, 'Item': 'доставкой', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['ресторан', 'грузинской', 'кухни'] ['ресторан' 'грузинской'] [ True  True False]
# {'Offer_type': 0, 'Attributes': 'ресторан грузинской', 'Price_from': 0, 'Item': 'кухни', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# unknown word -  тренажерного
# ['одежду', 'для', 'тренажерного'] ['одежду' 'тренажерного'] [ True False  True]
# {'Offer_type': 0, 'Attributes': 'одежду тренажерного', 'Price_from': 0, 'Item': 'для', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['специальное', 'предложение', 'спорт'] ['предложение' 'спорт'] [False  True  True]
# {'Offer_type': 0, 'Attributes': 'предложение спорт', 'Price_from': 0, 'Item': 'специальное', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['очки', 'для', 'плавания'] ['очки' 'плавания'] [ True False  True]
# {'Offer_type': 0, 'Attributes': 'очки плавания', 'Price_from': 0, 'Item': 'для', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['лыжную', 'куртку'] ['куртку'] [False  True]
# {'Offer_type': 0, 'Attributes': 'куртку', 'Price_from': 0, 'Item': 'лыжную', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# unknown word -  велотренажеры
# ['велотренажеры', 'самой', 'большой'] ['велотренажеры' 'самой'] [ True  True False]
# {'Offer_type': 0, 'Attributes': 'велотренажеры самой', 'Price_from': 0, 'Item': 'большой', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0.5, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['приобрести', 'грузинская'] ['грузинская'] [False  True]
# {'Offer_type': 0, 'Attributes': 'грузинская', 'Price_from': 0, 'Item': 'приобрести', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# unknown word -  кроссофки
# ['кроссофки', 'для', 'бега'] ['кроссофки' 'для'] [ True  True False]
# {'Offer_type': 0, 'Attributes': 'кроссофки для', 'Price_from': 0, 'Item': 'бега', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['можно', 'найти'] ['найти'] [False  True]
# {'Offer_type': 0, 'Attributes': 'найти', 'Price_from': 0, 'Item': 'можно', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['ананасы', 'приобрести'] ['приобрести'] [False  True]
# {'Offer_type': 0, 'Attributes': 'приобрести', 'Price_from': 0, 'Item': 'ананасы', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['комплект', 'финских'] ['комплект'] [ True False]
# {'Offer_type': 0, 'Attributes': 'комплект', 'Price_from': 0, 'Item': 'финских', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['доставка', 'еды'] ['доставка'] [ True False]
# {'Offer_type': 0, 'Attributes': 'доставка', 'Price_from': 0, 'Item': 'еды', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['коньки', 'burton'] ['burton'] [False  True]
# {'Offer_type': 0, 'Attributes': 'burton', 'Price_from': 0, 'Item': 'коньки', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# unknown word -  велотренажеры
# short word
# ['велотренажеры', 'самой', 'большой'] ['велотренажеры' 'самой'] [ True  True False]
# {'Offer_type': 0, 'Attributes': 'велотренажеры самой', 'Price_from': 0, 'Item': 'большой', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0.5, 'Offer_type_from': 0, 'Offer_type_to': 0}
# unknown word -  кешбеком
# ['кешбеком', 'макдональдс'] ['кешбеком'] [ True False]
# {'Offer_type': 0, 'Attributes': 'кешбеком', 'Price_from': 0, 'Item': 'макдональдс', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['заказать', 'ананасы'] ['заказать'] [ True False]
# {'Offer_type': 0, 'Attributes': 'заказать', 'Price_from': 0, 'Item': 'ананасы', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# short word
# ['самые', 'выгодные', 'цены', 'палатки', 'для'] ['самые' 'выгодные' 'цены' 'для'] [ True  True  True False  True]
# {'Offer_type': 0, 'Attributes': 'самые выгодные цены для', 'Price_from': 0, 'Item': 'палатки', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['лыжную', 'куртку'] ['куртку'] [False  True]
# {'Offer_type': 0, 'Attributes': 'куртку', 'Price_from': 0, 'Item': 'лыжную', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['хочу', 'поесть', 'осетинские'] ['хочу' 'осетинские'] [ True False  True]
# {'Offer_type': 0, 'Attributes': 'хочу осетинские', 'Price_from': 0, 'Item': 'поесть', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# unknown word -  дешевоом
# ['рестораны', 'поблизости', 'дешевоом'] ['поблизости' 'дешевоом'] [False  True  True]
# {'Offer_type': 0, 'Attributes': 'поблизости дешевоом', 'Price_from': 0, 'Item': 'рестораны', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['рестораны', 'поблизости'] ['поблизости'] [False  True]
# {'Offer_type': 0, 'Attributes': 'поблизости', 'Price_from': 0, 'Item': 'рестораны', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# short word
# ['приобрести', 'яблочный', 'пирог'] ['приобрести' 'пирог'] [ True False  True]
# {'Offer_type': 0, 'Attributes': 'приобрести пирог', 'Price_from': 0, 'Item': 'яблочный', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# unknown word -  вок
# ['хочу', 'вок'] ['вок'] [False  True]
# {'Offer_type': 0, 'Attributes': 'вок', 'Price_from': 0, 'Item': 'хочу', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# short word
# short word
# ['хочу', 'можно', 'найти', 'велосипед', 'горный'] ['хочу' 'можно' 'найти' 'горный'] [ True  True  True False  True]
# {'Offer_type': 0, 'Attributes': 'хочу можно найти горный', 'Price_from': 0, 'Item': 'велосипед', 'Price_to': 2015.0, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['футбольный', 'мяч', 'максимальным'] ['мяч' 'максимальным'] [False  True  True]
# {'Offer_type': 0, 'Attributes': 'мяч максимальным', 'Price_from': 0, 'Item': 'футбольный', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['можно', 'найти'] ['найти'] [False  True]
# {'Offer_type': 0, 'Attributes': 'найти', 'Price_from': 0, 'Item': 'можно', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['хочу', 'лыжную'] ['хочу'] [ True False]
# {'Offer_type': 0, 'Attributes': 'хочу', 'Price_from': 0, 'Item': 'лыжную', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['яблочный', 'пирог', 'можно'] ['пирог' 'можно'] [False  True  True]
# {'Offer_type': 0, 'Attributes': 'пирог можно', 'Price_from': 0, 'Item': 'яблочный', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['самая', 'дешевая'] ['самая'] [ True False]
# {'Offer_type': 0, 'Attributes': 'самая', 'Price_from': 0, 'Item': 'дешевая', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# short word
# ['по', 'самой', 'низкой'] ['по' 'низкой'] [ True False  True]
# {'Offer_type': 0, 'Attributes': 'по низкой', 'Price_from': 0, 'Item': 'самой', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['хочу', 'хоккейную', 'клюшку'] ['хочу' 'клюшку'] [ True False  True]
# {'Offer_type': 0, 'Attributes': 'хочу клюшку', 'Price_from': 0, 'Item': 'хоккейную', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['можно', 'хоккейную'] ['можно'] [ True False]
# {'Offer_type': 0, 'Attributes': 'можно', 'Price_from': 0, 'Item': 'хоккейную', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# short word
# ['мороженное', 'по'] ['по'] [False  True]
# {'Offer_type': 0, 'Attributes': 'по', 'Price_from': 0, 'Item': 'мороженное', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['хочу', 'беговые', 'лыжи'] ['хочу' 'лыжи'] [ True False  True]
# {'Offer_type': 0, 'Attributes': 'хочу лыжи', 'Price_from': 0, 'Item': 'беговые', 'Price_to': 15.0, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# short word
# ['можно', 'свежие', 'овощи'] ['можно' 'свежие'] [ True  True False]
# {'Offer_type': 0, 'Attributes': 'можно свежие', 'Price_from': 0, 'Item': 'овощи', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# unknown word -  дартс
# ['дартс', 'дешевле', 'чем'] ['дартс' 'чем'] [ True False  True]
# {'Offer_type': 0, 'Attributes': 'дартс чем', 'Price_from': 0, 'Item': 'дешевле', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# short word
# ['фигурный', 'коньки'] ['фигурный'] [ True False]
# {'Offer_type': 0, 'Attributes': 'фигурный', 'Price_from': 0, 'Item': 'коньки', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['горные', 'лыжи'] ['горные'] [ True False]
# {'Offer_type': 0, 'Attributes': 'горные', 'Price_from': 0, 'Item': 'лыжи', 'Price_to': 40000.0, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['одежду', 'для', 'сноуборда'] ['одежду' 'для'] [ True  True False]
# {'Offer_type': 0, 'Attributes': 'одежду для', 'Price_from': 0, 'Item': 'сноуборда', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['одежда', 'для', 'зимних'] ['для' 'зимних'] [False  True  True]
# {'Offer_type': 0, 'Attributes': 'для зимних', 'Price_from': 0, 'Item': 'одежда', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# short word
# ['доставка', 'еды', 'из'] ['доставка' 'из'] [ True False  True]
# {'Offer_type': 0, 'Attributes': 'доставка из', 'Price_from': 0, 'Item': 'еды', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# {'Offer_type': 0, 'Attributes': '', 'Price_from': 0, 'Item': 'велосипед', 'Price_to': 20000.0, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['беговые', 'лыжи'] ['лыжи'] [False  True]
# {'Offer_type': 0, 'Attributes': 'лыжи', 'Price_from': 0, 'Item': 'беговые', 'Price_to': 15.0, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# short word
# ['очки', 'для', 'плавания', 'хочу'] ['очки' 'плавания' 'хочу'] [ True False  True  True]
# {'Offer_type': 0, 'Attributes': 'очки плавания хочу', 'Price_from': 0, 'Item': 'для', 'Price_to': 9999999, 'Cashback': 0.5, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# unknown word -  кроссофки
# ['самые', 'выгодные', 'цены', 'кроссофки', 'для'] ['самые' 'выгодные' 'кроссофки' 'для'] [ True  True False  True  True]
# {'Offer_type': 0, 'Attributes': 'самые выгодные кроссофки для', 'Price_from': 0, 'Item': 'цены', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# {'Offer_type': 0, 'Attributes': '', 'Price_from': 0, 'Item': 'приобрести', 'Price_to': 9999999, 'Cashback': 10.0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# short word
# ['заказать', 'сладкий', 'стол'] ['заказать' 'стол'] [ True False  True]
# {'Offer_type': 0, 'Attributes': 'заказать стол', 'Price_from': 0, 'Item': 'сладкий', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# ['лыжные', 'палки', 'можно'] ['палки' 'можно'] [False  True  True]
# {'Offer_type': 0, 'Attributes': 'палки можно', 'Price_from': 0, 'Item': 'лыжные', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}
# short word
# ['доставка', 'из'] ['из'] [False  True]
# {'Offer_type': 0, 'Attributes': 'из', 'Price_from': 0, 'Item': 'доставка', 'Price_to': 9999999, 'Cashback': 0, 'Sale': 0, 'Offer_type_from': 0, 'Offer_type_to': 0}

# %%
for i,result in enumerate(results):
    with open('out2/queri{}.json'.format(i), 'w') as outfile:
        json.dump(result, outfile)

# %%
# Out:
# {'offer': {'offer': 'Tramontana', 'web': 'https://tramontana.ru/', 'cashback': 9, 'period': 0, 'offer_type': 0, 'advert_text': 'the north face, arcteryx, salomon и десятки других брендов в outdoor-центре «трамонтана». профессиональные консультации, бесплатная доставка, быстрый и простой обмен и возврат товара, и любые формы оплаты сделают покупку удобной и безопасной. спецпредложение распространяется при оплате картой на сайте, а так же в магазине на ул. бронницкая, 24.'}, 'products': [{'Item': 'походное снаряжение~туристические палатки~двухместные палатки~палатка nemo chogori 2p', 'Attributes': 'эта палатка относится к полупрофессиональной серии четырёхсезонных палаток под названием chogori tent, которая проектировалась непосредственно для использования в горных условиях. в серии изначально представлено только две версии — двухместный и трёхместный вариант. среди основных преимуществ новинки, производитель выделяет относительно быструю установку, прочный внешний каркас, вместительный тамбур и возможность стыковки двух палаток в единую систему.\nгорные палатки серии nemo chogori предусматривают двухслойную конструкцию с внешним алюминиевым каркасом из облегчённых и прочных 9.6 мм дуг марки dac featherlite nsl. \nтент палаток выполнен из армированного рип-стоп нейлона с двусторонней силиконовой и огнеупорной обработкой, плотность используемого материала не более 30 денье, водостойкость 1500 мм вд. ст. \nдля формирования дна используется ламинированные полиуретаном нейлон общей плотностью в 70 денье, водостойкость не менее 7000 мм вд. ст. \nсама палатка сделана из материала рип-стоп нейлон и вставки из вентилируемой сетки.\nконструктивно палатка предусматривают два тамбура и два отдельных входа, снежную юбку на основном тамбуре, несколько вентиляционных каналов, крепление под фонарь или лампу, а также несколько эластичных карманов для размещения личных вещей.', 'Price': 56100}, {'Item': 'походное снаряжение~туристические палатки~двухместные палатки~палатка nemo chogori 2p', 'Attributes': 'эта палатка относится к полупрофессиональной серии четырёхсезонных палаток под названием chogori tent, которая проектировалась непосредственно для использования в горных условиях. в серии изначально представлено только две версии — двухместный и трёхместный вариант. среди основных преимуществ новинки, производитель выделяет относительно быструю установку, прочный внешний каркас, вместительный тамбур и возможность стыковки двух палаток в единую систему.\nгорные палатки серии nemo chogori предусматривают двухслойную конструкцию с внешним алюминиевым каркасом из облегчённых и прочных 9.6 мм дуг марки dac featherlite nsl. \nтент палаток выполнен из армированного рип-стоп нейлона с двусторонней силиконовой и огнеупорной обработкой, плотность используемого материала не более 30 денье, водостойкость 1500 мм вд. ст. \nдля формирования дна используется ламинированные полиуретаном нейлон общей плотностью в 70 денье, водостойкость не менее 7000 мм вд. ст. \nсама палатка сделана из материала рип-стоп нейлон и вставки из вентилируемой сетки.\nконструктивно палатка предусматривают два тамбура и два отдельных входа, снежную юбку на основном тамбуре, несколько вентиляционных каналов, крепление под фонарь или лампу, а также несколько эластичных карманов для размещения личных вещей.', 'Price': 56100}, {'Item': 'походное снаряжение~туристические палатки~двухместные палатки~палатка nemo chogori 2p', 'Attributes': 'эта палатка относится к полупрофессиональной серии четырёхсезонных палаток под названием chogori tent, которая проектировалась непосредственно для использования в горных условиях. в серии изначально представлено только две версии — двухместный и трёхместный вариант. среди основных преимуществ новинки, производитель выделяет относительно быструю установку, прочный внешний каркас, вместительный тамбур и возможность стыковки двух палаток в единую систему.\nгорные палатки серии nemo chogori предусматривают двухслойную конструкцию с внешним алюминиевым каркас ...
